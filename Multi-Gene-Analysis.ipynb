# %%
import pandas as pd
from IPython.display import display
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import dendrogram, linkage
from tabulate import tabulate

# DATA LOADING FROM EXCEL FILE

data = pd.read_excel(r'C:\Users\agnie\OneDrive\Pulpit\MultiGene.xls')
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(data)


# TIME SERIES ANALYSIS

# Extract the growth stages
growth_stages = data['sample name']

# Extract gene expression levels for ech gene
gene_ctu2 = data['CTU2']
gene_trm9 = data['TRM9']
gene_urm12 = data['URM12']
gene_cnx5 = data['CNX5']
gene_urm11 = data['URM11']

# Plot the time series for ech gene
plt.figure(figsize=(12, 6))
plt.plot(growth_stages, gene_ctu2, marker='o', linestyle='-', color='b')
plt.xticks(rotation=90)
plt.xlabel('Growth Stages')
plt.ylabel('Gene Expression Level')
plt.title('Time Series Analysis for Gene CTU2')
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(growth_stages, gene_trm9, marker='o', linestyle='-', color='b')
plt.xticks(rotation=90)
plt.xlabel('Growth Stages')
plt.ylabel('Gene Expression Level')
plt.title('Time Series Analysis for Gene TRM9')
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(growth_stages, gene_urm12, marker='o', linestyle='-', color='b')
plt.xticks(rotation=90)
plt.xlabel('Growth Stages')
plt.ylabel('Gene Expression Level')
plt.title('Time Series Analysis for Gene URM12')
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(growth_stages, gene_cnx5, marker='o', linestyle='-', color='b')
plt.xticks(rotation=90)
plt.xlabel('Growth Stages')
plt.ylabel('Gene Expression Level')
plt.title('Time Series Analysis for Gene CNX5')
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(growth_stages, gene_urm11, marker='o', linestyle='-', color='b')
plt.xticks(rotation=90)
plt.xlabel('Growth Stages')
plt.ylabel('Gene Expression Level')
plt.title('Time Series Analysis for Gene URM11')
plt.grid(True)
plt.tight_layout()
plt.show()


# MEAN EXPRESSION LEVELS AND BAR PLOT

# Calculate the mean expression level for each gene and sort the genes in descending order based on mean expression levels
mean_expression = data.iloc[:, 1:].mean().sort_values(ascending=False)
print(mean_expression)

# Set up the figure and axes for plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Define the colormap with the number of colors equal to the number of genes
num_genes = len(mean_expression)
colormap = plt.cm.get_cmap('viridis', num_genes)

# Plot the average gene expression levels using a bar plot with a custom colormap
for i, (gene, expression) in enumerate(mean_expression.items()):
    ax.bar(gene, expression, color=colormap(i))

ax.set_xlabel('Gene')
ax.set_ylabel('Mean Relative Gene Expression Level')
ax.set_title('Graph of Mean Relative Gene Expression Levels')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()


# TABLE OF AVERAGE EXPRESSION 

# Remove the 'sample name' column from the data
data = data.drop(columns='sample name')

# Calculate the average level of gene expression for each stage
average_expression = data.mean(axis=1)
average_expression_rounded = average_expression.round(3)

# Create a DataFrame to store the results
results_1 = pd.DataFrame({'Growth Stage': growth_stages,
                        'Average Expression': average_expression_rounded})

# Sort the developmental stages based on the average expression values
sorted_results = results_1.sort_values(by='Average Expression', ascending=False)

# Display the sorted growth stages and average expression values in a table
table_data = sorted_results[['Growth Stage', 'Average Expression']].values.tolist()
table_headers = ['Growth Stage', 'Average Expression']
table = tabulate(table_data, headers=table_headers, tablefmt='pretty')

print("Sorted Growth Stages based on Average Expression:")
print(table)


# GENES WITH THE LOWEST AND HIGHEST EXPRESSION FOR EACH GROWTH STAGE

# Find the gene with the lowest and highest expression for each growth stage
lowest_genes = data.idxmin(axis=1)
highest_genes = data.idxmax(axis=1)

# Create a DataFrame to store the results
results_2 = pd.DataFrame({'Growth Stage': growth_stages,
                        'The Gene With The Lowest Expression': lowest_genes,
                        'The Gene With The Highest Expression': highest_genes})

# Count the occurrences of each gene in the 'Gene with Lowest Expression' and 'Gene with Highest Expression' column
lowest_gene_counts = results_2['The Gene With The Lowest Expression'].value_counts()
highest_gene_counts = results_2['The Gene With The Highest Expression'].value_counts()

# Find the gene that appears most often with the lowest and highest expression
most_often_lowest = lowest_gene_counts.idxmax()
most_often_highest = highest_gene_counts.idxmax()

# Sort genes from most often to least often expressed (lowest expression)
sorted_lowest_genes = lowest_gene_counts.sort_values(ascending=False)
# Sort genes from most often to least often expressed (highest expression)
sorted_highest_genes = highest_gene_counts.sort_values(ascending=False)

# Display the gene that most often has the lowest and highest expression levels
print(f"The gene that most often has the highest level of expression: {most_often_highest}")
print(f"\nThe gene that most often has the lowest expression level: {most_often_lowest}")

# Display genes sorted from most often to least often expressed (highest expression)
print("\nGenes that most often have the highest expression levels:")
print(sorted_highest_genes)
# Display genes sorted from most often to least often expressed (lowest expression)
print("\nGenes that most often have the lowest expression levels:")
print(sorted_lowest_genes)

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(results_2)
    
    
# CORRELATION HEATMAP 

# Calculate the correlation matrix for gene expression levels
correlation_matrix = data.corr()

# Create the heatmap and customize it
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
ax.set_title('Correlation Heatmap: Gene Expression Levels')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()


# HIERARCHICAL CLUSTERING

# Read data from the Excel file
gene_expression_data = pd.read_excel(r'C:\Users\agnie\OneDrive\Pulpit\MultiGene.xls', index_col=0 )

# Standardize the data (scaling to mean=0 and variance=1)
scaler = StandardScaler()
data_scaled = scaler.fit_transform(gene_expression_data)

# Calculate the distance matrix using Euclidean distance
distance_matrix = pdist(data_scaled, metric='euclidean')

# Perform hierarchical clustering using linkage
linkage_matrix = linkage(distance_matrix, method='ward')

plt.figure(figsize=(10, 8))
dendrogram(linkage_matrix, labels=gene_expression_data.index, orientation='right')
plt.xlabel('Distance')
plt.ylabel('Genes')
plt.title('Hierarchical Clustering Dendrogram')
plt.tight_layout()
plt.show()
# Out:
#                                           sample name  CTU2  TRM9  URM12  \
# 0                              STI - Stigmatic tissue  0.67  0.47   0.15
# 1               F.PT.ad - Petals of the mature flower  0.46  0.37   0.37
# 2     F.FM.ad - Stamen filaments of the mature flower  0.40  0.26   0.60
# 3               F.SP.ad - Sepals of the mature flower  0.23  0.47   0.99
# 4                 F.SP.y - Sepals of the young flower  0.46  0.40   0.12
# 5                           S.C - Seedling cotyledons  0.46  0.31   0.39
# 6               L.LAM.i1 - Leaf blade, intermediate 1  0.52  0.37   0.21
# 7              L.LAM.y - Leaf blade of the young leaf  0.46  0.34   0.11
# 8               L.LAM.i2 - Leaf blade, intermediate 2  0.42  0.39   0.42
# 9                 L.VN.i2 - Leaf vein, intermediate 2  0.44  0.39   0.26
# 10                        POD7 - Pod of the silique 7  0.31  0.35   0.18
# 11                        POD5 - Pod of the silique 5  0.28  0.38   0.39
# 12                        POD3 - Pod of the silique 3  0.30  0.34   0.27
# 13                        POD1 - Pod of the silique 1  0.31  0.34   0.31
# 14                                    SL2 - Silique 2  0.31  0.27   0.29
# 15                                    SL6 - Silique 6  0.28  0.29   0.43
# 16                                    SL4 - Silique 4  0.28  0.24   0.34
# 17                                    SL8 - Silique 8  0.34  0.26   0.27
# 18  SD.g3 - Germinating seeds 3 (third day after s...  0.40  0.25   0.21
# 19                                      PED - Pedicel  0.47  0.45   0.30
# 20                 L.PET.i1 - Petiole, intermediate 1  0.49  0.35   0.18
# 21                 L.PET.i2 - Petiole, intermediate 2  0.37  0.44   0.43
# 22                                     IN - Internode  0.41  0.34   0.84
# 23                     AX - Axis of the inflorescence  0.51  0.42   0.30
# 24                L.PET.y - Petiole of the young leaf  0.51  0.29   0.35
# 25               M1 - SAM at 7 days after germination  1.00  0.20   0.84
# 26               M2 - SAM at 8 days after germination  0.65  0.19   0.79
# 27               M3 - SAM at 9 days after germination  0.74  0.16   0.58
# 28         M5 - Meristem at 11 days after germination  0.47  0.14   1.00
# 29         M4 - Meristem at 10 days after germination  0.78  0.36   0.39
# 30  M7 - Inflorescence meristem at 13 days after g...  0.68  0.35   0.25
# 31         M6 - Meristem at 12 days after germination  0.57  0.27   0.29
# 32  M8 - Inflorescence meristem at 14 days after g...  0.63  0.23   0.34
# 33  M9 - Inflorescence meristem at 15 days after g...  0.50  0.30   0.19
# 34  M10 - Inflorescence meristem at 16 days after ...  0.49  0.43   0.15
# 35                                 F19+ - Flower 19+   0.50  0.37   0.12
# 36               F.CA.y - Carpels of the young flower  0.52  0.37   0.09
# 37                            S.M - Seedling meristem  0.62  0.22   0.46
# 38                                    R.A - Root apex  0.62  0.25   0.11
# 39                                S.R - Seedling root  0.75  0.29   0.10
# 40                              R - Root without apex  0.49  0.45   0.13
# 41          OV.y6-7 - Ovules from 6th and 7th flowers  0.55  0.35   0.16
# 42                              SD.y5 - Young seeds 5  0.41  0.33   0.43
# 43                              SD.y4 - Young seeds 4  0.66  0.28   0.28
# 44                              SD.y3 - Young seeds 3  0.55  0.38   0.15
# 45                              SD.y2 - Young seeds 2  0.43  0.42   0.29
# 46                              SD.y1 - Young seeds 1  0.44  0.39   0.23
# 47  F.CA.ad - Carpels of the mature flower (before...  0.55  0.33   0.22
# 48           POD.y6-7 - Carpel of 6th and 7th flowers  0.59  0.54   0.20
# 49                                     F1 - Flower 1   0.43  0.40   0.55
# 50                                     F2 - Flower 2   0.48  0.39   0.37
# 51                                     F3 - Flower 3   0.41  0.40   0.43
# 52                                     F4 - Flower 4   0.38  0.40   0.16
# 53                                     F5 - Flower 5   0.40  0.37   0.23
# 54                                 F6-8 - Flower 6-8   0.43  0.39   0.29
# 55                               F9-11 - Flower 9-11   0.51  0.35   0.34
# 56                             F12-14 - Flower 12-14   0.51  0.40   0.14
# 57                             F15-18 - Flower 15-18   0.45  0.36   0.16
# 58               F.AN.y - Anthers of the young flower  0.71  0.22   0.22
# 59  SD.g2 - Germinating seeds 2 (second day after ...  0.55  0.21   0.13
# 60  SD.g1 - Germinating seeds 1 (first day after s...  0.60  0.54   0.33
# 61               L.VN.sn - Vein of the senescent leaf  0.26  0.62   0.64
# 62           L.PET.sn - Petiole of the senescent leaf  0.35  0.52   0.23
# 63                       IN.sn - Senescent internode.  0.39  0.45   0.25
# 64                           L.lg - Whole mature leaf  0.31  0.69   0.54
# 65           L.LAM.lg - Leaf blade of the mature leaf  0.29  0.59   0.32
# 66                  L.VN.lg - Vein of the mature leaf  0.34  0.57   0.47
# 67              L.PET.lg - Petiole of the mature leaf  0.41  0.50   0.39
# 68                           S.H - Seedling hypocotyl  0.36  0.43   0.28
# 69          POD.sn1 - Pod of the senescent silique 1.  0.42  0.54   0.85
# 70                                      SD7 - Seeds 7  0.33  0.37   0.33
# 71                                      SD5 - Seeds 5  0.41  0.31   0.19
# 72                                      SD3 - Seeds 3  0.28  0.29   0.36
# 73                                      SD1 - Seeds 1  0.41  0.22   0.21
# 74                       SL.sn2 - Senescent silique 2  0.64  0.71   0.23
# 75         SD.sn1 - Seeds of first yellowing silique.  0.60  0.59   0.01
# 76                                   SD.d - Dry seeds  0.77  1.00   0.07
# 77  F.AN.ad - Anthers of the mature flower (before...  0.28  0.26   0.14
# 78                              F.AN - Opened anthers  0.44  0.23   0.45
#
#     CNX5  URM11
# 0   0.31   0.18
# 1   0.25   0.18
# 2   0.22   0.16
# 3   0.39   0.18
# 4   0.39   0.17
# 5   0.39   0.32
# 6   0.41   0.17
# 7   0.48   0.18
# 8   0.43   0.20
# 9   0.47   0.16
# 10  0.25   0.12
# 11  0.24   0.16
# 12  0.30   0.20
# 13  0.35   0.20
# 14  0.35   0.28
# 15  0.33   0.25
# 16  0.31   0.28
# 17  0.36   0.18
# 18  0.37   0.14
# 19  0.44   0.18
# 20  0.52   0.17
# 21  0.46   0.14
# 22  0.39   0.18
# 23  0.62   0.23
# 24  0.71   0.20
# 25  0.74   0.32
# 26  0.76   0.41
# 27  0.86   0.35
# 28  0.87   0.55
# 29  1.00   0.32
# 30  0.86   0.27
# 31  0.80   0.27
# 32  0.81   0.28
# 33  0.64   0.33
# 34  0.61   0.37
# 35  0.60   0.24
# 36  0.63   0.35
# 37  0.81   0.86
# 38  0.59   0.20
# 39  0.68   0.20
# 40  0.54   0.24
# 41  0.65   0.29
# 42  0.68   0.42
# 43  0.76   0.31
# 44  0.60   0.26
# 45  0.55   0.32
# 46  0.55   0.36
# 47  0.54   0.31
# 48  0.57   0.21
# 49  0.54   0.32
# 50  0.46   0.19
# 51  0.41   0.20
# 52  0.35   0.19
# 53  0.37   0.17
# 54  0.40   0.19
# 55  0.51   0.31
# 56  0.48   0.20
# 57  0.45   0.23
# 58  0.38   0.23
# 59  0.45   0.20
# 60  0.77   1.00
# 61  0.64   0.25
# 62  0.86   0.22
# 63  0.70   0.26
# 64  0.49   0.24
# 65  0.54   0.18
# 66  0.56   0.19
# 67  0.60   0.22
# 68  0.55   0.22
# 69  0.35   0.21
# 70  0.47   0.35
# 71  0.43   0.39
# 72  0.43   0.39
# 73  0.53   0.51
# 74  0.48   0.55
# 75  0.62   0.71
# 76  0.45   0.60
# 77  0.08   0.19
# 78  0.14   0.11
# CNX5     0.518101
# CTU2     0.473797
# TRM9     0.375949
# URM12    0.326709
# URM11    0.279367
# dtype: float64
# Sorted Growth Stages based on Average Expression:
# +------------------------------------------------------------+--------------------+
# |                        Growth Stage                        | Average Expression |
# +------------------------------------------------------------+--------------------+
# |   SD.g1 - Germinating seeds 1 (first day after soaking)    |       0.648        |
# |            M1 - SAM at 7 days after germination            |        0.62        |
# |         M5 - Meristem at 11 days after germination         |       0.606        |
# |                  S.M - Seedling meristem                   |       0.594        |
# |                      SD.d - Dry seeds                      |       0.578        |
# |         M4 - Meristem at 10 days after germination         |        0.57        |
# |            M2 - SAM at 8 days after germination            |        0.56        |
# |            M3 - SAM at 9 days after germination            |       0.538        |
# |                SL.sn2 - Senescent silique 2                |       0.522        |
# |         SD.sn1 - Seeds of first yellowing silique.         |       0.506        |
# |            L.VN.sn - Vein of the senescent leaf            |       0.482        |
# |  M7 - Inflorescence meristem at 13 days after germination  |       0.482        |
# |         POD.sn1 - Pod of the senescent silique 1.          |       0.474        |
# |                   SD.y4 - Young seeds 4                    |       0.458        |
# |  M8 - Inflorescence meristem at 14 days after germination  |       0.458        |
# |                   SD.y5 - Young seeds 5                    |       0.454        |
# |                  L.lg - Whole mature leaf                  |       0.454        |
# |           F.SP.ad - Sepals of the mature flower            |       0.452        |
# |                       F1 - Flower 1                        |       0.448        |
# |         M6 - Meristem at 12 days after germination         |        0.44        |
# |          L.PET.sn - Petiole of the senescent leaf          |       0.436        |
# |                       IN - Internode                       |       0.432        |
# |             L.VN.lg - Vein of the mature leaf              |       0.426        |
# |           L.PET.lg - Petiole of the mature leaf            |       0.424        |
# |          POD.y6-7 - Carpel of 6th and 7th flowers          |       0.422        |
# |               AX - Axis of the inflorescence               |       0.416        |
# |            L.PET.y - Petiole of the young leaf             |       0.412        |
# | M10 - Inflorescence meristem at 16 days after germination  |        0.41        |
# |                IN.sn - Senescent internode.                |        0.41        |
# |                    F9-11 - Flower 9-11                     |       0.404        |
# |                    S.R - Seedling root                     |       0.404        |
# |                   SD.y2 - Young seeds 2                    |       0.402        |
# |         OV.y6-7 - Ovules from 6th and 7th flowers          |        0.4         |
# |                   SD.y1 - Young seeds 1                    |       0.394        |
# |  M9 - Inflorescence meristem at 15 days after germination  |       0.392        |
# |            F.CA.y - Carpels of the young flower            |       0.392        |
# | F.CA.ad - Carpels of the mature flower (before pollination |        0.39        |
# |                   SD.y3 - Young seeds 3                    |       0.388        |
# |          L.LAM.lg - Leaf blade of the mature leaf          |       0.384        |
# |                       F2 - Flower 2                        |       0.378        |
# |                       SD1 - Seeds 1                        |       0.376        |
# |                 S.C - Seedling cotyledons                  |       0.374        |
# |           L.LAM.i2 - Leaf blade, intermediate 2            |       0.372        |
# |                   R - Root without apex                    |        0.37        |
# |                       F3 - Flower 3                        |        0.37        |
# |                       SD7 - Seeds 7                        |        0.37        |
# |             L.PET.i2 - Petiole, intermediate 2             |       0.368        |
# |                  S.H - Seedling hypocotyl                  |       0.368        |
# |                       PED - Pedicel                        |       0.368        |
# |                     F19+ - Flower 19+                      |       0.366        |
# |                   STI - Stigmatic tissue                   |       0.356        |
# |                      R.A - Root apex                       |       0.354        |
# |            F.AN.y - Anthers of the young flower            |       0.352        |
# |                       SD3 - Seeds 3                        |        0.35        |
# |                       SD5 - Seeds 5                        |       0.346        |
# |                   F12-14 - Flower 12-14                    |       0.346        |
# |            L.VN.i2 - Leaf vein, intermediate 2             |       0.344        |
# |             L.PET.i1 - Petiole, intermediate 1             |       0.342        |
# |                     F6-8 - Flower 6-8                      |        0.34        |
# |           L.LAM.i1 - Leaf blade, intermediate 1            |       0.336        |
# |                   F15-18 - Flower 15-18                    |        0.33        |
# |      F.FM.ad - Stamen filaments of the mature flower       |       0.328        |
# |           F.PT.ad - Petals of the mature flower            |       0.326        |
# |                      SL6 - Silique 6                       |       0.316        |
# |           L.LAM.y - Leaf blade of the young leaf           |       0.314        |
# |   SD.g2 - Germinating seeds 2 (second day after soaking)   |       0.308        |
# |            F.SP.y - Sepals of the young flower             |       0.308        |
# |                       F5 - Flower 5                        |       0.308        |
# |                POD1 - Pod of the silique 1                 |       0.302        |
# |                      SL2 - Silique 2                       |        0.3         |
# |                       F4 - Flower 4                        |       0.296        |
# |                POD5 - Pod of the silique 5                 |        0.29        |
# |                      SL4 - Silique 4                       |        0.29        |
# |                POD3 - Pod of the silique 3                 |       0.282        |
# |                      SL8 - Silique 8                       |       0.282        |
# |   SD.g3 - Germinating seeds 3 (third day after soaking)    |       0.274        |
# |                   F.AN - Opened anthers                    |       0.274        |
# |                POD7 - Pod of the silique 7                 |       0.242        |
# |  F.AN.ad - Anthers of the mature flower (before opening).  |        0.19        |
# +------------------------------------------------------------+--------------------+
# The gene that most often has the highest level of expression: CNX5
#
# The gene that most often has the lowest expression level: URM11
#
# Genes that most often have the highest expression levels:
# CNX5     34
# CTU2     21
# URM12    13
# TRM9      8
# URM11     3
# Name: The Gene With The Highest Expression, dtype: int64
#
# Genes that most often have the lowest expression levels:
# URM11    35
# URM12    28
# TRM9     13
# CTU2      2
# CNX5      1
# Name: The Gene With The Lowest Expression, dtype: int64
#                                          Growth Stage  \
# 0                              STI - Stigmatic tissue
# 1               F.PT.ad - Petals of the mature flower
# 2     F.FM.ad - Stamen filaments of the mature flower
# 3               F.SP.ad - Sepals of the mature flower
# 4                 F.SP.y - Sepals of the young flower
# 5                           S.C - Seedling cotyledons
# 6               L.LAM.i1 - Leaf blade, intermediate 1
# 7              L.LAM.y - Leaf blade of the young leaf
# 8               L.LAM.i2 - Leaf blade, intermediate 2
# 9                 L.VN.i2 - Leaf vein, intermediate 2
# 10                        POD7 - Pod of the silique 7
# 11                        POD5 - Pod of the silique 5
# 12                        POD3 - Pod of the silique 3
# 13                        POD1 - Pod of the silique 1
# 14                                    SL2 - Silique 2
# 15                                    SL6 - Silique 6
# 16                                    SL4 - Silique 4
# 17                                    SL8 - Silique 8
# 18  SD.g3 - Germinating seeds 3 (third day after s...
# 19                                      PED - Pedicel
# 20                 L.PET.i1 - Petiole, intermediate 1
# 21                 L.PET.i2 - Petiole, intermediate 2
# 22                                     IN - Internode
# 23                     AX - Axis of the inflorescence
# 24                L.PET.y - Petiole of the young leaf
# 25               M1 - SAM at 7 days after germination
# 26               M2 - SAM at 8 days after germination
# 27               M3 - SAM at 9 days after germination
# 28         M5 - Meristem at 11 days after germination
# 29         M4 - Meristem at 10 days after germination
# 30  M7 - Inflorescence meristem at 13 days after g...
# 31         M6 - Meristem at 12 days after germination
# 32  M8 - Inflorescence meristem at 14 days after g...
# 33  M9 - Inflorescence meristem at 15 days after g...
# 34  M10 - Inflorescence meristem at 16 days after ...
# 35                                 F19+ - Flower 19+
# 36               F.CA.y - Carpels of the young flower
# 37                            S.M - Seedling meristem
# 38                                    R.A - Root apex
# 39                                S.R - Seedling root
# 40                              R - Root without apex
# 41          OV.y6-7 - Ovules from 6th and 7th flowers
# 42                              SD.y5 - Young seeds 5
# 43                              SD.y4 - Young seeds 4
# 44                              SD.y3 - Young seeds 3
# 45                              SD.y2 - Young seeds 2
# 46                              SD.y1 - Young seeds 1
# 47  F.CA.ad - Carpels of the mature flower (before...
# 48           POD.y6-7 - Carpel of 6th and 7th flowers
# 49                                     F1 - Flower 1
# 50                                     F2 - Flower 2
# 51                                     F3 - Flower 3
# 52                                     F4 - Flower 4
# 53                                     F5 - Flower 5
# 54                                 F6-8 - Flower 6-8
# 55                               F9-11 - Flower 9-11
# 56                             F12-14 - Flower 12-14
# 57                             F15-18 - Flower 15-18
# 58               F.AN.y - Anthers of the young flower
# 59  SD.g2 - Germinating seeds 2 (second day after ...
# 60  SD.g1 - Germinating seeds 1 (first day after s...
# 61               L.VN.sn - Vein of the senescent leaf
# 62           L.PET.sn - Petiole of the senescent leaf
# 63                       IN.sn - Senescent internode.
# 64                           L.lg - Whole mature leaf
# 65           L.LAM.lg - Leaf blade of the mature leaf
# 66                  L.VN.lg - Vein of the mature leaf
# 67              L.PET.lg - Petiole of the mature leaf
# 68                           S.H - Seedling hypocotyl
# 69          POD.sn1 - Pod of the senescent silique 1.
# 70                                      SD7 - Seeds 7
# 71                                      SD5 - Seeds 5
# 72                                      SD3 - Seeds 3
# 73                                      SD1 - Seeds 1
# 74                       SL.sn2 - Senescent silique 2
# 75         SD.sn1 - Seeds of first yellowing silique.
# 76                                   SD.d - Dry seeds
# 77  F.AN.ad - Anthers of the mature flower (before...
# 78                              F.AN - Opened anthers
#
#    The Gene With The Lowest Expression The Gene With The Highest Expression
# 0                                URM12                                 CTU2
# 1                                URM11                                 CTU2
# 2                                URM11                                URM12
# 3                                URM11                                URM12
# 4                                URM12                                 CTU2
# 5                                 TRM9                                 CTU2
# 6                                URM11                                 CTU2
# 7                                URM12                                 CNX5
# 8                                URM11                                 CNX5
# 9                                URM11                                 CNX5
# 10                               URM11                                 TRM9
# 11                               URM11                                URM12
# 12                               URM11                                 TRM9
# 13                               URM11                                 CNX5
# 14                                TRM9                                 CNX5
# 15                               URM11                                URM12
# 16                                TRM9                                URM12
# 17                               URM11                                 CNX5
# 18                               URM11                                 CTU2
# 19                               URM11                                 CTU2
# 20                               URM11                                 CNX5
# 21                               URM11                                 CNX5
# 22                               URM11                                URM12
# 23                               URM11                                 CNX5
# 24                               URM11                                 CNX5
# 25                                TRM9                                 CTU2
# 26                                TRM9                                URM12
# 27                                TRM9                                 CNX5
# 28                                TRM9                                URM12
# 29                               URM11                                 CNX5
# 30                               URM12                                 CNX5
# 31                                TRM9                                 CNX5
# 32                                TRM9                                 CNX5
# 33                               URM12                                 CNX5
# 34                               URM12                                 CNX5
# 35                               URM12                                 CNX5
# 36                               URM12                                 CNX5
# 37                                TRM9                                URM11
# 38                               URM12                                 CTU2
# 39                               URM12                                 CTU2
# 40                               URM12                                 CNX5
# 41                               URM12                                 CNX5
# 42                                TRM9                                 CNX5
# 43                                TRM9                                 CNX5
# 44                               URM12                                 CNX5
# 45                               URM12                                 CNX5
# 46                               URM12                                 CNX5
# 47                               URM12                                 CTU2
# 48                               URM12                                 CTU2
# 49                               URM11                                URM12
# 50                               URM11                                 CTU2
# 51                               URM11                                URM12
# 52                               URM12                                 TRM9
# 53                               URM11                                 CTU2
# 54                               URM11                                 CTU2
# 55                               URM11                                 CTU2
# 56                               URM12                                 CTU2
# 57                               URM12                                 CTU2
# 58                                TRM9                                 CTU2
# 59                               URM12                                 CTU2
# 60                               URM12                                URM11
# 61                               URM11                                URM12
# 62                               URM11                                 CNX5
# 63                               URM12                                 CNX5
# 64                               URM11                                 TRM9
# 65                               URM11                                 TRM9
# 66                               URM11                                 TRM9
# 67                               URM11                                 CNX5
# 68                               URM11                                 CNX5
# 69                               URM11                                URM12
# 70                                CTU2                                 CNX5
# 71                               URM12                                 CNX5
# 72                                CTU2                                 CNX5
# 73                               URM12                                 CNX5
# 74                               URM12                                 TRM9
# 75                               URM12                                URM11
# 76                               URM12                                 TRM9
# 77                                CNX5                                 CTU2
# 78                               URM11                                URM12
